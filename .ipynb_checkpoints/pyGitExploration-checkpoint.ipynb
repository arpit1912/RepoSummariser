# %%
import pip
pip.main(['install', 'PyGithub'])
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Requirement already satisfied: PyGithub in c:\users\user\anaconda3\lib\site-packages (1.54.1)
# Requirement already satisfied: deprecated in c:\users\user\anaconda3\lib\site-packages (from PyGithub) (1.2.11)
# Requirement already satisfied: pyjwt<2.0 in c:\users\user\anaconda3\lib\site-packages (from PyGithub) (1.7.1)
# Requirement already satisfied: requests>=2.14.0 in c:\users\user\anaconda3\lib\site-packages (from PyGithub) (2.22.0)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\user\anaconda3\lib\site-packages (from deprecated->PyGithub) (1.11.2)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.14.0->PyGithub) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.14.0->PyGithub) (1.25.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.14.0->PyGithub) (2019.11.28)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\user\anaconda3\lib\site-packages (from requests>=2.14.0->PyGithub) (3.0.4)
# 0

# %%
# 24a99d486e39c3c7f1c814d55535a93bb864ee06 
# arpit1912 Token for the Github Api

# %% [markdown]
# ## Importing Libraries

# %%
from github import Github
import requests
import os
from pprint import pprint

# %%
#token = "24a99d486e39c3c7f1c814d55535a93bb864ee06"
token = "30a4ce706658fe0f00abdf0e09d2fb81958ace41";
g = Github(token)

# %%
main_repo = g.get_repo("oppia/oppia")

# %%
users = main_repo.get_contributors()

# %%
print(users)
# Out:
# <github.PaginatedList.PaginatedList object at 0x0000022A2115E708>

# %%
# Fetching all the Data Related to the Repo
owner = "arpit1912"
repo = "oppia"
query_url = f"https://api.github.com/repos/{owner}/{repo}"
params = {
    "state": "open",
}
headers = {'Authorization': f'token {token}'}
r = requests.get(query_url, headers=headers, params=params)

pprint(r.json())
# Out:
# {'archive_url': 'https://api.github.com/repos/arpit1912/oppia/{archive_format}{/ref}',
#  'archived': False,
#  'assignees_url': 'https://api.github.com/repos/arpit1912/oppia/assignees{/user}',
#  'blobs_url': 'https://api.github.com/repos/arpit1912/oppia/git/blobs{/sha}',
#  'branches_url': 'https://api.github.com/repos/arpit1912/oppia/branches{/branch}',
#  'clone_url': 'https://github.com/arpit1912/oppia.git',
#  'collaborators_url': 'https://api.github.com/repos/arpit1912/oppia/collaborators{/collaborator}',
#  'comments_url': 'https://api.github.com/repos/arpit1912/oppia/comments{/number}',
#  'commits_url': 'https://api.github.com/repos/arpit1912/oppia/commits{/sha}',
#  'compare_url': 'https://api.github.com/repos/arpit1912/oppia/compare/{base}...{head}',
#  'contents_url': 'https://api.github.com/repos/arpit1912/oppia/contents/{+path}',
#  'contributors_url': 'https://api.github.com/repos/arpit1912/oppia/contributors',
#  'created_at': '2020-09-05T18:01:26Z',
#  'default_branch': 'develop',
#  'deployments_url': 'https://api.github.com/repos/arpit1912/oppia/deployments',
#  'description': 'A free, online learning platform to make quality education '
#                 'accessible for all.',
#  'disabled': False,
#  'downloads_url': 'https://api.github.com/repos/arpit1912/oppia/downloads',
#  'events_url': 'https://api.github.com/repos/arpit1912/oppia/events',
#  'fork': True,
#  'forks': 0,
#  'forks_count': 0,
#  'forks_url': 'https://api.github.com/repos/arpit1912/oppia/forks',
#  'full_name': 'arpit1912/oppia',
#  'git_commits_url': 'https://api.github.com/repos/arpit1912/oppia/git/commits{/sha}',
#  'git_refs_url': 'https://api.github.com/repos/arpit1912/oppia/git/refs{/sha}',
#  'git_tags_url': 'https://api.github.com/repos/arpit1912/oppia/git/tags{/sha}',
#  'git_url': 'git://github.com/arpit1912/oppia.git',
#  'has_downloads': False,
#  'has_issues': False,
#  'has_pages': False,
#  'has_projects': True,
#  'has_wiki': True,
#  'homepage': 'https://www.oppia.org',
#  'hooks_url': 'https://api.github.com/repos/arpit1912/oppia/hooks',
#  'html_url': 'https://github.com/arpit1912/oppia',
#  'id': 293128465,
#  'issue_comment_url': 'https://api.github.com/repos/arpit1912/oppia/issues/comments{/number}',
#  'issue_events_url': 'https://api.github.com/repos/arpit1912/oppia/issues/events{/number}',
#  'issues_url': 'https://api.github.com/repos/arpit1912/oppia/issues{/number}',
#  'keys_url': 'https://api.github.com/repos/arpit1912/oppia/keys{/key_id}',
#  'labels_url': 'https://api.github.com/repos/arpit1912/oppia/labels{/name}',
#  'language': 'Python',
#  'languages_url': 'https://api.github.com/repos/arpit1912/oppia/languages',
#  'license': {'key': 'apache-2.0',
#              'name': 'Apache License 2.0',
#              'node_id': 'MDc6TGljZW5zZTI=',
#              'spdx_id': 'Apache-2.0',
#              'url': 'https://api.github.com/licenses/apache-2.0'},
#  'merges_url': 'https://api.github.com/repos/arpit1912/oppia/merges',
#  'milestones_url': 'https://api.github.com/repos/arpit1912/oppia/milestones{/number}',
#  'mirror_url': None,
#  'name': 'oppia',
#  'network_count': 1724,
#  'node_id': 'MDEwOlJlcG9zaXRvcnkyOTMxMjg0NjU=',
#  'notifications_url': 'https://api.github.com/repos/arpit1912/oppia/notifications{?since,all,participating}',
#  'open_issues': 0,
#  'open_issues_count': 0,
#  'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/46648172?v=4',
#            'events_url': 'https://api.github.com/users/arpit1912/events{/privacy}',
#            'followers_url': 'https://api.github.com/users/arpit1912/followers',
#            'following_url': 'https://api.github.com/users/arpit1912/following{/other_user}',
#            'gists_url': 'https://api.github.com/users/arpit1912/gists{/gist_id}',
#            'gravatar_id': '',
#            'html_url': 'https://github.com/arpit1912',
#            'id': 46648172,
#            'login': 'arpit1912',
#            'node_id': 'MDQ6VXNlcjQ2NjQ4MTcy',
#            'organizations_url': 'https://api.github.com/users/arpit1912/orgs',
#            'received_events_url': 'https://api.github.com/users/arpit1912/received_events',
#            'repos_url': 'https://api.github.com/users/arpit1912/repos',
#            'site_admin': False,
#            'starred_url': 'https://api.github.com/users/arpit1912/starred{/owner}{/repo}',
#            'subscriptions_url': 'https://api.github.com/users/arpit1912/subscriptions',
#            'type': 'User',
#            'url': 'https://api.github.com/users/arpit1912'},
#  'parent': {'archive_url': 'https://api.github.com/repos/oppia/oppia/{archive_format}{/ref}',
#             'archived': False,
#             'assignees_url': 'https://api.github.com/repos/oppia/oppia/assignees{/user}',
#             'blobs_url': 'https://api.github.com/repos/oppia/oppia/git/blobs{/sha}',
#             'branches_url': 'https://api.github.com/repos/oppia/oppia/branches{/branch}',
#             'clone_url': 'https://github.com/oppia/oppia.git',
#             'collaborators_url': 'https://api.github.com/repos/oppia/oppia/collaborators{/collaborator}',
#             'comments_url': 'https://api.github.com/repos/oppia/oppia/comments{/number}',
#             'commits_url': 'https://api.github.com/repos/oppia/oppia/commits{/sha}',
#             'compare_url': 'https://api.github.com/repos/oppia/oppia/compare/{base}...{head}',
#             'contents_url': 'https://api.github.com/repos/oppia/oppia/contents/{+path}',
#             'contributors_url': 'https://api.github.com/repos/oppia/oppia/contributors',
#             'created_at': '2015-08-14T00:16:14Z',
#             'default_branch': 'develop',
#             'deployments_url': 'https://api.github.com/repos/oppia/oppia/deployments',
#             'description': 'A free, online learning platform to make quality '
#                            'education accessible for all.',
#             'disabled': False,
#             'downloads_url': 'https://api.github.com/repos/oppia/oppia/downloads',
#             'events_url': 'https://api.github.com/repos/oppia/oppia/events',
#             'fork': False,
#             'forks': 1724,
#             'forks_count': 1724,
#             'forks_url': 'https://api.github.com/repos/oppia/oppia/forks',
#             'full_name': 'oppia/oppia',
#             'git_commits_url': 'https://api.github.com/repos/oppia/oppia/git/commits{/sha}',
#             'git_refs_url': 'https://api.github.com/repos/oppia/oppia/git/refs{/sha}',
#             'git_tags_url': 'https://api.github.com/repos/oppia/oppia/git/tags{/sha}',
#             'git_url': 'git://github.com/oppia/oppia.git',
#             'has_downloads': False,
#             'has_issues': True,
#             'has_pages': False,
#             'has_projects': True,
#             'has_wiki': True,
#             'homepage': 'https://www.oppia.org',
#             'hooks_url': 'https://api.github.com/repos/oppia/oppia/hooks',
#             'html_url': 'https://github.com/oppia/oppia',
#             'id': 40687563,
#             'issue_comment_url': 'https://api.github.com/repos/oppia/oppia/issues/comments{/number}',
#             'issue_events_url': 'https://api.github.com/repos/oppia/oppia/issues/events{/number}',
#             'issues_url': 'https://api.github.com/repos/oppia/oppia/issues{/number}',
#             'keys_url': 'https://api.github.com/repos/oppia/oppia/keys{/key_id}',
#             'labels_url': 'https://api.github.com/repos/oppia/oppia/labels{/name}',
#             'language': 'Python',
#             'languages_url': 'https://api.github.com/repos/oppia/oppia/languages',
#             'license': {'key': 'apache-2.0',
#                         'name': 'Apache License 2.0',
#                         'node_id': 'MDc6TGljZW5zZTI=',
#                         'spdx_id': 'Apache-2.0',
#                         'url': 'https://api.github.com/licenses/apache-2.0'},
#             'merges_url': 'https://api.github.com/repos/oppia/oppia/merges',
#             'milestones_url': 'https://api.github.com/repos/oppia/oppia/milestones{/number}',
#             'mirror_url': None,
#             'name': 'oppia',
#             'node_id': 'MDEwOlJlcG9zaXRvcnk0MDY4NzU2Mw==',
#             'notifications_url': 'https://api.github.com/repos/oppia/oppia/notifications{?since,all,participating}',
#             'open_issues': 971,
#             'open_issues_count': 971,
#             'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/11620230?v=4',
#                       'events_url': 'https://api.github.com/users/oppia/events{/privacy}',
#                       'followers_url': 'https://api.github.com/users/oppia/followers',
#                       'following_url': 'https://api.github.com/users/oppia/following{/other_user}',
#                       'gists_url': 'https://api.github.com/users/oppia/gists{/gist_id}',
#                       'gravatar_id': '',
#                       'html_url': 'https://github.com/oppia',
#                       'id': 11620230,
#                       'login': 'oppia',
#                       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjExNjIwMjMw',
#                       'organizations_url': 'https://api.github.com/users/oppia/orgs',
#                       'received_events_url': 'https://api.github.com/users/oppia/received_events',
#                       'repos_url': 'https://api.github.com/users/oppia/repos',
#                       'site_admin': False,
#                       'starred_url': 'https://api.github.com/users/oppia/starred{/owner}{/repo}',
#                       'subscriptions_url': 'https://api.github.com/users/oppia/subscriptions',
#                       'type': 'Organization',
#                       'url': 'https://api.github.com/users/oppia'},
#             'private': False,
#             'pulls_url': 'https://api.github.com/repos/oppia/oppia/pulls{/number}',
#             'pushed_at': '2021-03-03T05:45:59Z',
#             'releases_url': 'https://api.github.com/repos/oppia/oppia/releases{/id}',
#             'size': 173883,
#             'ssh_url': 'git@github.com:oppia/oppia.git',
#             'stargazers_count': 1649,
#             'stargazers_url': 'https://api.github.com/repos/oppia/oppia/stargazers',
#             'statuses_url': 'https://api.github.com/repos/oppia/oppia/statuses/{sha}',
#             'subscribers_url': 'https://api.github.com/repos/oppia/oppia/subscribers',
#             'subscription_url': 'https://api.github.com/repos/oppia/oppia/subscription',
#             'svn_url': 'https://github.com/oppia/oppia',
#             'tags_url': 'https://api.github.com/repos/oppia/oppia/tags',
#             'teams_url': 'https://api.github.com/repos/oppia/oppia/teams',
#             'trees_url': 'https://api.github.com/repos/oppia/oppia/git/trees{/sha}',
#             'updated_at': '2021-03-03T02:22:02Z',
#             'url': 'https://api.github.com/repos/oppia/oppia',
#             'watchers': 1649,
#             'watchers_count': 1649},
#  'permissions': {'admin': False, 'pull': True, 'push': False},
#  'private': False,
#  'pulls_url': 'https://api.github.com/repos/arpit1912/oppia/pulls{/number}',
#  'pushed_at': '2021-02-28T09:34:05Z',
#  'releases_url': 'https://api.github.com/repos/arpit1912/oppia/releases{/id}',
#  'size': 173125,
#  'source': {'archive_url': 'https://api.github.com/repos/oppia/oppia/{archive_format}{/ref}',
#             'archived': False,
#             'assignees_url': 'https://api.github.com/repos/oppia/oppia/assignees{/user}',
#             'blobs_url': 'https://api.github.com/repos/oppia/oppia/git/blobs{/sha}',
#             'branches_url': 'https://api.github.com/repos/oppia/oppia/branches{/branch}',
#             'clone_url': 'https://github.com/oppia/oppia.git',
#             'collaborators_url': 'https://api.github.com/repos/oppia/oppia/collaborators{/collaborator}',
#             'comments_url': 'https://api.github.com/repos/oppia/oppia/comments{/number}',
#             'commits_url': 'https://api.github.com/repos/oppia/oppia/commits{/sha}',
#             'compare_url': 'https://api.github.com/repos/oppia/oppia/compare/{base}...{head}',
#             'contents_url': 'https://api.github.com/repos/oppia/oppia/contents/{+path}',
#             'contributors_url': 'https://api.github.com/repos/oppia/oppia/contributors',
#             'created_at': '2015-08-14T00:16:14Z',
#             'default_branch': 'develop',
#             'deployments_url': 'https://api.github.com/repos/oppia/oppia/deployments',
#             'description': 'A free, online learning platform to make quality '
#                            'education accessible for all.',
#             'disabled': False,
#             'downloads_url': 'https://api.github.com/repos/oppia/oppia/downloads',
#             'events_url': 'https://api.github.com/repos/oppia/oppia/events',
#             'fork': False,
#             'forks': 1724,
#             'forks_count': 1724,
#             'forks_url': 'https://api.github.com/repos/oppia/oppia/forks',
#             'full_name': 'oppia/oppia',
#             'git_commits_url': 'https://api.github.com/repos/oppia/oppia/git/commits{/sha}',
#             'git_refs_url': 'https://api.github.com/repos/oppia/oppia/git/refs{/sha}',
#             'git_tags_url': 'https://api.github.com/repos/oppia/oppia/git/tags{/sha}',
#             'git_url': 'git://github.com/oppia/oppia.git',
#             'has_downloads': False,
#             'has_issues': True,
#             'has_pages': False,
#             'has_projects': True,
#             'has_wiki': True,
#             'homepage': 'https://www.oppia.org',
#             'hooks_url': 'https://api.github.com/repos/oppia/oppia/hooks',
#             'html_url': 'https://github.com/oppia/oppia',
#             'id': 40687563,
#             'issue_comment_url': 'https://api.github.com/repos/oppia/oppia/issues/comments{/number}',
#             'issue_events_url': 'https://api.github.com/repos/oppia/oppia/issues/events{/number}',
#             'issues_url': 'https://api.github.com/repos/oppia/oppia/issues{/number}',
#             'keys_url': 'https://api.github.com/repos/oppia/oppia/keys{/key_id}',
#             'labels_url': 'https://api.github.com/repos/oppia/oppia/labels{/name}',
#             'language': 'Python',
#             'languages_url': 'https://api.github.com/repos/oppia/oppia/languages',
#             'license': {'key': 'apache-2.0',
#                         'name': 'Apache License 2.0',
#                         'node_id': 'MDc6TGljZW5zZTI=',
#                         'spdx_id': 'Apache-2.0',
#                         'url': 'https://api.github.com/licenses/apache-2.0'},
#             'merges_url': 'https://api.github.com/repos/oppia/oppia/merges',
#             'milestones_url': 'https://api.github.com/repos/oppia/oppia/milestones{/number}',
#             'mirror_url': None,
#             'name': 'oppia',
#             'node_id': 'MDEwOlJlcG9zaXRvcnk0MDY4NzU2Mw==',
#             'notifications_url': 'https://api.github.com/repos/oppia/oppia/notifications{?since,all,participating}',
#             'open_issues': 971,
#             'open_issues_count': 971,
#             'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/11620230?v=4',
#                       'events_url': 'https://api.github.com/users/oppia/events{/privacy}',
#                       'followers_url': 'https://api.github.com/users/oppia/followers',
#                       'following_url': 'https://api.github.com/users/oppia/following{/other_user}',
#                       'gists_url': 'https://api.github.com/users/oppia/gists{/gist_id}',
#                       'gravatar_id': '',
#                       'html_url': 'https://github.com/oppia',
#                       'id': 11620230,
#                       'login': 'oppia',
#                       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjExNjIwMjMw',
#                       'organizations_url': 'https://api.github.com/users/oppia/orgs',
#                       'received_events_url': 'https://api.github.com/users/oppia/received_events',
#                       'repos_url': 'https://api.github.com/users/oppia/repos',
#                       'site_admin': False,
#                       'starred_url': 'https://api.github.com/users/oppia/starred{/owner}{/repo}',
#                       'subscriptions_url': 'https://api.github.com/users/oppia/subscriptions',
#                       'type': 'Organization',
#                       'url': 'https://api.github.com/users/oppia'},
#             'private': False,
#             'pulls_url': 'https://api.github.com/repos/oppia/oppia/pulls{/number}',
#             'pushed_at': '2021-03-03T05:45:59Z',
#             'releases_url': 'https://api.github.com/repos/oppia/oppia/releases{/id}',
#             'size': 173883,
#             'ssh_url': 'git@github.com:oppia/oppia.git',
#             'stargazers_count': 1649,
#             'stargazers_url': 'https://api.github.com/repos/oppia/oppia/stargazers',
#             'statuses_url': 'https://api.github.com/repos/oppia/oppia/statuses/{sha}',
#             'subscribers_url': 'https://api.github.com/repos/oppia/oppia/subscribers',
#             'subscription_url': 'https://api.github.com/repos/oppia/oppia/subscription',
#             'svn_url': 'https://github.com/oppia/oppia',
#             'tags_url': 'https://api.github.com/repos/oppia/oppia/tags',
#             'teams_url': 'https://api.github.com/repos/oppia/oppia/teams',
#             'trees_url': 'https://api.github.com/repos/oppia/oppia/git/trees{/sha}',
#             'updated_at': '2021-03-03T02:22:02Z',
#             'url': 'https://api.github.com/repos/oppia/oppia',
#             'watchers': 1649,
#             'watchers_count': 1649},
#  'ssh_url': 'git@github.com:arpit1912/oppia.git',
#  'stargazers_count': 1,
#  'stargazers_url': 'https://api.github.com/repos/arpit1912/oppia/stargazers',
#  'statuses_url': 'https://api.github.com/repos/arpit1912/oppia/statuses/{sha}',
#  'subscribers_count': 0,
#  'subscribers_url': 'https://api.github.com/repos/arpit1912/oppia/subscribers',
#  'subscription_url': 'https://api.github.com/repos/arpit1912/oppia/subscription',
#  'svn_url': 'https://github.com/arpit1912/oppia',
#  'tags_url': 'https://api.github.com/repos/arpit1912/oppia/tags',
#  'teams_url': 'https://api.github.com/repos/arpit1912/oppia/teams',
#  'temp_clone_token': '',
#  'trees_url': 'https://api.github.com/repos/arpit1912/oppia/git/trees{/sha}',
#  'updated_at': '2021-02-23T04:23:55Z',
#  'url': 'https://api.github.com/repos/arpit1912/oppia',
#  'watchers': 1,
#  'watchers_count': 1}

# %%
json_data = r.json()

# %%
if json_data.get('source') != None:
    print(json_data['source']['full_name'])
# Out:
# oppia/oppia

# %%
owner = "arpit1912"
repo = "SE-gamedev"
query_url = f"https://api.github.com/repos/{owner}/{repo}/contributors"
params = {
    "state": "open",
}
headers = {'Authorization': f'token {token}'}
r = requests.get(query_url, headers=headers, params=params)

json_data = r.json()

# %%
pprint(json_data)
# Out:
# [{'avatar_url': 'https://avatars.githubusercontent.com/u/46648172?v=4',
#   'contributions': 45,
#   'events_url': 'https://api.github.com/users/arpit1912/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/arpit1912/followers',
#   'following_url': 'https://api.github.com/users/arpit1912/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/arpit1912/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/arpit1912',
#   'id': 46648172,
#   'login': 'arpit1912',
#   'node_id': 'MDQ6VXNlcjQ2NjQ4MTcy',
#   'organizations_url': 'https://api.github.com/users/arpit1912/orgs',
#   'received_events_url': 'https://api.github.com/users/arpit1912/received_events',
#   'repos_url': 'https://api.github.com/users/arpit1912/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/arpit1912/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/arpit1912/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/arpit1912'},
#  {'avatar_url': 'https://avatars.githubusercontent.com/u/54976429?v=4',
#   'contributions': 41,
#   'events_url': 'https://api.github.com/users/sam3926/events{/privacy}',
#   'followers_url': 'https://api.github.com/users/sam3926/followers',
#   'following_url': 'https://api.github.com/users/sam3926/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/sam3926/gists{/gist_id}',
#   'gravatar_id': '',
#   'html_url': 'https://github.com/sam3926',
#   'id': 54976429,
#   'login': 'sam3926',
#   'node_id': 'MDQ6VXNlcjU0OTc2NDI5',
#   'organizations_url': 'https://api.github.com/users/sam3926/orgs',
#   'received_events_url': 'https://api.github.com/users/sam3926/received_events',
#   'repos_url': 'https://api.github.com/users/sam3926/repos',
#   'site_admin': False,
#   'starred_url': 'https://api.github.com/users/sam3926/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/sam3926/subscriptions',
#   'type': 'User',
#   'url': 'https://api.github.com/users/sam3926'}]

# %%
# Saving Login List
user_names = []
for user in json_data:
    if user.get('login') != None:
        user_names.append(user['login'])
    #pprint(user)

print(user_names)
# Out:
# ['arpit1912', 'sam3926']

# %%
# Get All the Repos from the contributors
json_data = []
for username in user_names:
    print(username)
    query_url = f"https://api.github.com/users/{username}/repos"
    pprint(query_url)
    params = {
        "state": "open",
    }
    headers = {'Authorization': f'token {token}'}
    r = requests.get(query_url, headers=headers, params=params)
    json_data.append(r.json())
# Out:
# arpit1912
# 'https://api.github.com/users/arpit1912/repos'
# sam3926
# 'https://api.github.com/users/sam3926/repos'

# %%
pprint(json_data)
# Out:
# [[{'archive_url': 'https://api.github.com/repos/arpit1912/AlwaysHigh_Smart_traffic_management_Hack_2020_IITT/{archive_format}{/ref}',
#    'archived': False,
#    'assignees_url': 'https://api.github.com/repos/arpit1912/AlwaysHigh_Smart_traffic_management_Hack_2020_IITT/assignees{/user}',
#    'blobs_url': 'https://api.github.com/repos/arpit1912/AlwaysHigh_Smart_traffic_management_Hack_2020_IITT/git/blobs{/sha}',
#    'branches_url': 'https://api.github.com/repos/arpit1912/AlwaysHigh_Smart_traffic_management_Hack_2020_IITT/branches{/branch}',
#    'clone_url': 'https://github.com/arpit1912/AlwaysHigh_Smart_traffic_management_Hack_2020_IITT.git',
#    'collaborators_url': 'https://api.github.com/repos/arpit1912/AlwaysHigh_Smart_traffic_management_Hack_2020_IITT/collaborators{/collaborator}',
#    'comments_url': 'https://api.github.com/repos/arpit1912/AlwaysHigh_Smart_traffic_management_Hack_2020_IITT/comments{/number}',
#    'commits_url': 'https://api.github.com/repos/arpit1912/AlwaysHigh_Smart_traffic_management_Hack_2020_IITT/commits{/sha}',
#    'compare_url': 'https://api.github.com/repos/arpit1912/AlwaysHigh_Smart_traffic_management_Hack_2020_IITT/compare/{base}...{head}',
#    'contents_url': 'https://api.github.com/repos/arpit1912/AlwaysHigh_Smart_traffic_management_Hack_2020_IITT/contents/{+path}',
#    'contributors_url': 'https://api.github.com/repos/arpit1912/AlwaysHigh_Smart_traffic_management_Hack_2020_IITT/contributors',
#    'created_at': '2020-01-25T13:57:44Z',
#    'default_branch': 'master',
#    'deployments_url': 'https://api.github.com/repos/arpit1912/AlwaysHigh_Smart_traffic_management_Hack_2020_IITT/deployments',
#    'description': None,
#    'disabled': False,
#    'downloads_url': 'https://api.github.com/repos/arpit1912/AlwaysHigh_Smart_traffic_management_Hack_2020_IITT/downloads',
#    'events_url': 'https://api.github.com/repos/arpit1912/AlwaysHigh_Smart_traffic_management_Hack_2020_IITT/events',
#    'fork': False,
#    'forks': 0,
#    'forks_count': 0,
#    'forks_url': 'https://api.github.com/repos/arpit1912/AlwaysHigh_Smart_traffic_management_Hack_2020_IITT/forks',
#    'full_name': 'arpit1912/AlwaysHigh_Smart_traffic_management_Hack_2020_IITT',
#    'git_commits_url': 'https://api.github.com/repos/arpit1912/AlwaysHigh_Smart_traffic_management_Hack_2020_IITT/git/commits{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/arpit1912/AlwaysHigh_Smart_traffic_management_Hack_2020_IITT/git/refs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/arpit1912/AlwaysHigh_Smart_traffic_management_Hack_2020_IITT/git/tags{/sha}',
#    'git_url': 'git://github.com/arpit1912/AlwaysHigh_Smart_traffic_management_Hack_2020_IITT.git',
#    'has_downloads': True,
#    'has_issues': True,
#    'has_pages': False,
#    'has_projects': True,
#    'has_wiki': True,
#    'homepage': None,
#    'hooks_url': 'https://api.github.com/repos/arpit1912/AlwaysHigh_Smart_traffic_management_Hack_2020_IITT/hooks',
#    'html_url': 'https://github.com/arpit1912/AlwaysHigh_Smart_traffic_management_Hack_2020_IITT',
#    'id': 236177067,
#    'issue_comment_url': 'https://api.github.com/repos/arpit1912/AlwaysHigh_Smart_traffic_management_Hack_2020_IITT/issues/comments{/number}',
#    'issue_events_url': 'https://api.github.com/repos/arpit1912/AlwaysHigh_Smart_traffic_management_Hack_2020_IITT/issues/events{/number}',
#    'issues_url': 'https://api.github.com/repos/arpit1912/AlwaysHigh_Smart_traffic_management_Hack_2020_IITT/issues{/number}',
#    'keys_url': 'https://api.github.com/repos/arpit1912/AlwaysHigh_Smart_traffic_management_Hack_2020_IITT/keys{/key_id}',
#    'labels_url': 'https://api.github.com/repos/arpit1912/AlwaysHigh_Smart_traffic_management_Hack_2020_IITT/labels{/name}',
#    'language': 'PHP',
#    'languages_url': 'https://api.github.com/repos/arpit1912/AlwaysHigh_Smart_traffic_management_Hack_2020_IITT/languages',
#    'license': None,
#    'merges_url': 'https://api.github.com/repos/arpit1912/AlwaysHigh_Smart_traffic_management_Hack_2020_IITT/merges',
#    'milestones_url': 'https://api.github.com/repos/arpit1912/AlwaysHigh_Smart_traffic_management_Hack_2020_IITT/milestones{/number}',
#    'mirror_url': None,
#    'name': 'AlwaysHigh_Smart_traffic_management_Hack_2020_IITT',
#    'node_id': 'MDEwOlJlcG9zaXRvcnkyMzYxNzcwNjc=',
#    'notifications_url': 'https://api.github.com/repos/arpit1912/AlwaysHigh_Smart_traffic_management_Hack_2020_IITT/notifications{?since,all,participating}',
#    'open_issues': 0,
#    'open_issues_count': 0,
#    'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/46648172?v=4',
#              'events_url': 'https://api.github.com/users/arpit1912/events{/privacy}',
#              'followers_url': 'https://api.github.com/users/arpit1912/followers',
#              'following_url': 'https://api.github.com/users/arpit1912/following{/other_user}',
#              'gists_url': 'https://api.github.com/users/arpit1912/gists{/gist_id}',
#              'gravatar_id': '',
#              'html_url': 'https://github.com/arpit1912',
#              'id': 46648172,
#              'login': 'arpit1912',
#              'node_id': 'MDQ6VXNlcjQ2NjQ4MTcy',
#              'organizations_url': 'https://api.github.com/users/arpit1912/orgs',
#              'received_events_url': 'https://api.github.com/users/arpit1912/received_events',
#              'repos_url': 'https://api.github.com/users/arpit1912/repos',
#              'site_admin': False,
#              'starred_url': 'https://api.github.com/users/arpit1912/starred{/owner}{/repo}',
#              'subscriptions_url': 'https://api.github.com/users/arpit1912/subscriptions',
#              'type': 'User',
#              'url': 'https://api.github.com/users/arpit1912'},
#    'permissions': {'admin': False, 'pull': True, 'push': False},
#    'private': False,
#    'pulls_url': 'https://api.github.com/repos/arpit1912/AlwaysHigh_Smart_traffic_management_Hack_2020_IITT/pulls{/number}',
#    'pushed_at': '2020-01-26T12:59:48Z',
#    'releases_url': 'https://api.github.com/repos/arpit1912/AlwaysHigh_Smart_traffic_management_Hack_2020_IITT/releases{/id}',
#    'size': 13,
#    'ssh_url': 'git@github.com:arpit1912/AlwaysHigh_Smart_traffic_management_Hack_2020_IITT.git',
#    'stargazers_count': 0,
#    'stargazers_url': 'https://api.github.com/repos/arpit1912/AlwaysHigh_Smart_traffic_management_Hack_2020_IITT/stargazers',
#    'statuses_url': 'https://api.github.com/repos/arpit1912/AlwaysHigh_Smart_traffic_management_Hack_2020_IITT/statuses/{sha}',
#    'subscribers_url': 'https://api.github.com/repos/arpit1912/AlwaysHigh_Smart_traffic_management_Hack_2020_IITT/subscribers',
#    'subscription_url': 'https://api.github.com/repos/arpit1912/AlwaysHigh_Smart_traffic_management_Hack_2020_IITT/subscription',
#    'svn_url': 'https://github.com/arpit1912/AlwaysHigh_Smart_traffic_management_Hack_2020_IITT',
#    'tags_url': 'https://api.github.com/repos/arpit1912/AlwaysHigh_Smart_traffic_management_Hack_2020_IITT/tags',
#    'teams_url': 'https://api.github.com/repos/arpit1912/AlwaysHigh_Smart_traffic_management_Hack_2020_IITT/teams',
#    'trees_url': 'https://api.github.com/repos/arpit1912/AlwaysHigh_Smart_traffic_management_Hack_2020_IITT/git/trees{/sha}',
#    'updated_at': '2020-01-26T12:59:50Z',
#    'url': 'https://api.github.com/repos/arpit1912/AlwaysHigh_Smart_traffic_management_Hack_2020_IITT',
#    'watchers': 0,
#    'watchers_count': 0},
#   {'archive_url': 'https://api.github.com/repos/arpit1912/atom/{archive_format}{/ref}',
#    'archived': False,
#    'assignees_url': 'https://api.github.com/repos/arpit1912/atom/assignees{/user}',
#    'blobs_url': 'https://api.github.com/repos/arpit1912/atom/git/blobs{/sha}',
#    'branches_url': 'https://api.github.com/repos/arpit1912/atom/branches{/branch}',
#    'clone_url': 'https://github.com/arpit1912/atom.git',
#    'collaborators_url': 'https://api.github.com/repos/arpit1912/atom/collaborators{/collaborator}',
#    'comments_url': 'https://api.github.com/repos/arpit1912/atom/comments{/number}',
#    'commits_url': 'https://api.github.com/repos/arpit1912/atom/commits{/sha}',
#    'compare_url': 'https://api.github.com/repos/arpit1912/atom/compare/{base}...{head}',
#    'contents_url': 'https://api.github.com/repos/arpit1912/atom/contents/{+path}',
#    'contributors_url': 'https://api.github.com/repos/arpit1912/atom/contributors',
#    'created_at': '2019-08-19T17:28:04Z',
#    'default_branch': 'master',
#    'deployments_url': 'https://api.github.com/repos/arpit1912/atom/deployments',
#    'description': ':atom: The hackable text editor',
#    'disabled': False,
#    'downloads_url': 'https://api.github.com/repos/arpit1912/atom/downloads',
#    'events_url': 'https://api.github.com/repos/arpit1912/atom/events',
#    'fork': True,
#    'forks': 0,
#    'forks_count': 0,
#    'forks_url': 'https://api.github.com/repos/arpit1912/atom/forks',
#    'full_name': 'arpit1912/atom',
#    'git_commits_url': 'https://api.github.com/repos/arpit1912/atom/git/commits{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/arpit1912/atom/git/refs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/arpit1912/atom/git/tags{/sha}',
#    'git_url': 'git://github.com/arpit1912/atom.git',
#    'has_downloads': True,
#    'has_issues': False,
#    'has_pages': False,
#    'has_projects': True,
#    'has_wiki': False,
#    'homepage': 'https://atom.io',
#    'hooks_url': 'https://api.github.com/repos/arpit1912/atom/hooks',
#    'html_url': 'https://github.com/arpit1912/atom',
#    'id': 203218799,
#    'issue_comment_url': 'https://api.github.com/repos/arpit1912/atom/issues/comments{/number}',
#    'issue_events_url': 'https://api.github.com/repos/arpit1912/atom/issues/events{/number}',
#    'issues_url': 'https://api.github.com/repos/arpit1912/atom/issues{/number}',
#    'keys_url': 'https://api.github.com/repos/arpit1912/atom/keys{/key_id}',
#    'labels_url': 'https://api.github.com/repos/arpit1912/atom/labels{/name}',
#    'language': 'JavaScript',
#    'languages_url': 'https://api.github.com/repos/arpit1912/atom/languages',
#    'license': {'key': 'mit',
#                'name': 'MIT License',
#                'node_id': 'MDc6TGljZW5zZTEz',
#                'spdx_id': 'MIT',
#                'url': 'https://api.github.com/licenses/mit'},
#    'merges_url': 'https://api.github.com/repos/arpit1912/atom/merges',
#    'milestones_url': 'https://api.github.com/repos/arpit1912/atom/milestones{/number}',
#    'mirror_url': None,
#    'name': 'atom',
#    'node_id': 'MDEwOlJlcG9zaXRvcnkyMDMyMTg3OTk=',
#    'notifications_url': 'https://api.github.com/repos/arpit1912/atom/notifications{?since,all,participating}',
#    'open_issues': 0,
#    'open_issues_count': 0,
#    'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/46648172?v=4',
#              'events_url': 'https://api.github.com/users/arpit1912/events{/privacy}',
#              'followers_url': 'https://api.github.com/users/arpit1912/followers',
#              'following_url': 'https://api.github.com/users/arpit1912/following{/other_user}',
#              'gists_url': 'https://api.github.com/users/arpit1912/gists{/gist_id}',
#              'gravatar_id': '',
#              'html_url': 'https://github.com/arpit1912',
#              'id': 46648172,
#              'login': 'arpit1912',
#              'node_id': 'MDQ6VXNlcjQ2NjQ4MTcy',
#              'organizations_url': 'https://api.github.com/users/arpit1912/orgs',
#              'received_events_url': 'https://api.github.com/users/arpit1912/received_events',
#              'repos_url': 'https://api.github.com/users/arpit1912/repos',
#              'site_admin': False,
#              'starred_url': 'https://api.github.com/users/arpit1912/starred{/owner}{/repo}',
#              'subscriptions_url': 'https://api.github.com/users/arpit1912/subscriptions',
#              'type': 'User',
#              'url': 'https://api.github.com/users/arpit1912'},
#    'permissions': {'admin': False, 'pull': True, 'push': False},
#    'private': False,
#    'pulls_url': 'https://api.github.com/repos/arpit1912/atom/pulls{/number}',
#    'pushed_at': '2019-08-19T17:18:58Z',
#    'releases_url': 'https://api.github.com/repos/arpit1912/atom/releases{/id}',
#    'size': 314038,
#    'ssh_url': 'git@github.com:arpit1912/atom.git',
#    'stargazers_count': 0,
#    'stargazers_url': 'https://api.github.com/repos/arpit1912/atom/stargazers',
#    'statuses_url': 'https://api.github.com/repos/arpit1912/atom/statuses/{sha}',
#    'subscribers_url': 'https://api.github.com/repos/arpit1912/atom/subscribers',
#    'subscription_url': 'https://api.github.com/repos/arpit1912/atom/subscription',
#    'svn_url': 'https://github.com/arpit1912/atom',
#    'tags_url': 'https://api.github.com/repos/arpit1912/atom/tags',
#    'teams_url': 'https://api.github.com/repos/arpit1912/atom/teams',
#    'trees_url': 'https://api.github.com/repos/arpit1912/atom/git/trees{/sha}',
#    'updated_at': '2019-08-19T17:28:08Z',
#    'url': 'https://api.github.com/repos/arpit1912/atom',
#    'watchers': 0,
#    'watchers_count': 0},
#   {'archive_url': 'https://api.github.com/repos/arpit1912/atom_project/{archive_format}{/ref}',
#    'archived': False,
#    'assignees_url': 'https://api.github.com/repos/arpit1912/atom_project/assignees{/user}',
#    'blobs_url': 'https://api.github.com/repos/arpit1912/atom_project/git/blobs{/sha}',
#    'branches_url': 'https://api.github.com/repos/arpit1912/atom_project/branches{/branch}',
#    'clone_url': 'https://github.com/arpit1912/atom_project.git',
#    'collaborators_url': 'https://api.github.com/repos/arpit1912/atom_project/collaborators{/collaborator}',
#    'comments_url': 'https://api.github.com/repos/arpit1912/atom_project/comments{/number}',
#    'commits_url': 'https://api.github.com/repos/arpit1912/atom_project/commits{/sha}',
#    'compare_url': 'https://api.github.com/repos/arpit1912/atom_project/compare/{base}...{head}',
#    'contents_url': 'https://api.github.com/repos/arpit1912/atom_project/contents/{+path}',
#    'contributors_url': 'https://api.github.com/repos/arpit1912/atom_project/contributors',
#    'created_at': '2019-08-19T17:20:22Z',
#    'default_branch': 'master',
#    'deployments_url': 'https://api.github.com/repos/arpit1912/atom_project/deployments',
#    'description': None,
#    'disabled': False,
#    'downloads_url': 'https://api.github.com/repos/arpit1912/atom_project/downloads',
#    'events_url': 'https://api.github.com/repos/arpit1912/atom_project/events',
#    'fork': False,
#    'forks': 0,
#    'forks_count': 0,
#    'forks_url': 'https://api.github.com/repos/arpit1912/atom_project/forks',
#    'full_name': 'arpit1912/atom_project',
#    'git_commits_url': 'https://api.github.com/repos/arpit1912/atom_project/git/commits{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/arpit1912/atom_project/git/refs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/arpit1912/atom_project/git/tags{/sha}',
#    'git_url': 'git://github.com/arpit1912/atom_project.git',
#    'has_downloads': True,
#    'has_issues': True,
#    'has_pages': False,
#    'has_projects': True,
#    'has_wiki': True,
#    'homepage': None,
#    'hooks_url': 'https://api.github.com/repos/arpit1912/atom_project/hooks',
#    'html_url': 'https://github.com/arpit1912/atom_project',
#    'id': 203217632,
#    'issue_comment_url': 'https://api.github.com/repos/arpit1912/atom_project/issues/comments{/number}',
#    'issue_events_url': 'https://api.github.com/repos/arpit1912/atom_project/issues/events{/number}',
#    'issues_url': 'https://api.github.com/repos/arpit1912/atom_project/issues{/number}',
#    'keys_url': 'https://api.github.com/repos/arpit1912/atom_project/keys{/key_id}',
#    'labels_url': 'https://api.github.com/repos/arpit1912/atom_project/labels{/name}',
#    'language': None,
#    'languages_url': 'https://api.github.com/repos/arpit1912/atom_project/languages',
#    'license': None,
#    'merges_url': 'https://api.github.com/repos/arpit1912/atom_project/merges',
#    'milestones_url': 'https://api.github.com/repos/arpit1912/atom_project/milestones{/number}',
#    'mirror_url': None,
#    'name': 'atom_project',
#    'node_id': 'MDEwOlJlcG9zaXRvcnkyMDMyMTc2MzI=',
#    'notifications_url': 'https://api.github.com/repos/arpit1912/atom_project/notifications{?since,all,participating}',
#    'open_issues': 0,
#    'open_issues_count': 0,
#    'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/46648172?v=4',
#              'events_url': 'https://api.github.com/users/arpit1912/events{/privacy}',
#              'followers_url': 'https://api.github.com/users/arpit1912/followers',
#              'following_url': 'https://api.github.com/users/arpit1912/following{/other_user}',
#              'gists_url': 'https://api.github.com/users/arpit1912/gists{/gist_id}',
#              'gravatar_id': '',
#              'html_url': 'https://github.com/arpit1912',
#              'id': 46648172,
#              'login': 'arpit1912',
#              'node_id': 'MDQ6VXNlcjQ2NjQ4MTcy',
#              'organizations_url': 'https://api.github.com/users/arpit1912/orgs',
#              'received_events_url': 'https://api.github.com/users/arpit1912/received_events',
#              'repos_url': 'https://api.github.com/users/arpit1912/repos',
#              'site_admin': False,
#              'starred_url': 'https://api.github.com/users/arpit1912/starred{/owner}{/repo}',
#              'subscriptions_url': 'https://api.github.com/users/arpit1912/subscriptions',
#              'type': 'User',
#              'url': 'https://api.github.com/users/arpit1912'},
#    'permissions': {'admin': False, 'pull': True, 'push': False},
#    'private': False,
#    'pulls_url': 'https://api.github.com/repos/arpit1912/atom_project/pulls{/number}',
#    'pushed_at': '2019-08-19T17:20:23Z',
#    'releases_url': 'https://api.github.com/repos/arpit1912/atom_project/releases{/id}',
#    'size': 0,
#    'ssh_url': 'git@github.com:arpit1912/atom_project.git',
#    'stargazers_count': 0,
#    'stargazers_url': 'https://api.github.com/repos/arpit1912/atom_project/stargazers',
#    'statuses_url': 'https://api.github.com/repos/arpit1912/atom_project/statuses/{sha}',
#    'subscribers_url': 'https://api.github.com/repos/arpit1912/atom_project/subscribers',
#    'subscription_url': 'https://api.github.com/repos/arpit1912/atom_project/subscription',
#    'svn_url': 'https://github.com/arpit1912/atom_project',
#    'tags_url': 'https://api.github.com/repos/arpit1912/atom_project/tags',
#    'teams_url': 'https://api.github.com/repos/arpit1912/atom_project/teams',
#    'trees_url': 'https://api.github.com/repos/arpit1912/atom_project/git/trees{/sha}',
#    'updated_at': '2019-08-19T17:20:22Z',
#    'url': 'https://api.github.com/repos/arpit1912/atom_project',
#    'watchers': 0,
#    'watchers_count': 0},
#   {'archive_url': 'https://api.github.com/repos/arpit1912/book_review_panel/{archive_format}{/ref}',
#    'archived': False,
#    'assignees_url': 'https://api.github.com/repos/arpit1912/book_review_panel/assignees{/user}',
#    'blobs_url': 'https://api.github.com/repos/arpit1912/book_review_panel/git/blobs{/sha}',
#    'branches_url': 'https://api.github.com/repos/arpit1912/book_review_panel/branches{/branch}',
#    'clone_url': 'https://github.com/arpit1912/book_review_panel.git',
#    'collaborators_url': 'https://api.github.com/repos/arpit1912/book_review_panel/collaborators{/collaborator}',
#    'comments_url': 'https://api.github.com/repos/arpit1912/book_review_panel/comments{/number}',
#    'commits_url': 'https://api.github.com/repos/arpit1912/book_review_panel/commits{/sha}',
#    'compare_url': 'https://api.github.com/repos/arpit1912/book_review_panel/compare/{base}...{head}',
#    'contents_url': 'https://api.github.com/repos/arpit1912/book_review_panel/contents/{+path}',
#    'contributors_url': 'https://api.github.com/repos/arpit1912/book_review_panel/contributors',
#    'created_at': '2020-05-21T20:11:23Z',
#    'default_branch': 'master',
#    'deployments_url': 'https://api.github.com/repos/arpit1912/book_review_panel/deployments',
#    'description': None,
#    'disabled': False,
#    'downloads_url': 'https://api.github.com/repos/arpit1912/book_review_panel/downloads',
#    'events_url': 'https://api.github.com/repos/arpit1912/book_review_panel/events',
#    'fork': False,
#    'forks': 0,
#    'forks_count': 0,
#    'forks_url': 'https://api.github.com/repos/arpit1912/book_review_panel/forks',
#    'full_name': 'arpit1912/book_review_panel',
#    'git_commits_url': 'https://api.github.com/repos/arpit1912/book_review_panel/git/commits{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/arpit1912/book_review_panel/git/refs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/arpit1912/book_review_panel/git/tags{/sha}',
#    'git_url': 'git://github.com/arpit1912/book_review_panel.git',
#    'has_downloads': True,
#    'has_issues': True,
#    'has_pages': False,
#    'has_projects': True,
#    'has_wiki': True,
#    'homepage': None,
#    'hooks_url': 'https://api.github.com/repos/arpit1912/book_review_panel/hooks',
#    'html_url': 'https://github.com/arpit1912/book_review_panel',
#    'id': 265942198,
#    'issue_comment_url': 'https://api.github.com/repos/arpit1912/book_review_panel/issues/comments{/number}',
#    'issue_events_url': 'https://api.github.com/repos/arpit1912/book_review_panel/issues/events{/number}',
#    'issues_url': 'https://api.github.com/repos/arpit1912/book_review_panel/issues{/number}',
#    'keys_url': 'https://api.github.com/repos/arpit1912/book_review_panel/keys{/key_id}',
#    'labels_url': 'https://api.github.com/repos/arpit1912/book_review_panel/labels{/name}',
#    'language': 'HTML',
#    'languages_url': 'https://api.github.com/repos/arpit1912/book_review_panel/languages',
#    'license': None,
#    'merges_url': 'https://api.github.com/repos/arpit1912/book_review_panel/merges',
#    'milestones_url': 'https://api.github.com/repos/arpit1912/book_review_panel/milestones{/number}',
#    'mirror_url': None,
#    'name': 'book_review_panel',
#    'node_id': 'MDEwOlJlcG9zaXRvcnkyNjU5NDIxOTg=',
#    'notifications_url': 'https://api.github.com/repos/arpit1912/book_review_panel/notifications{?since,all,participating}',
#    'open_issues': 1,
#    'open_issues_count': 1,
#    'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/46648172?v=4',
#              'events_url': 'https://api.github.com/users/arpit1912/events{/privacy}',
#              'followers_url': 'https://api.github.com/users/arpit1912/followers',
#              'following_url': 'https://api.github.com/users/arpit1912/following{/other_user}',
#              'gists_url': 'https://api.github.com/users/arpit1912/gists{/gist_id}',
#              'gravatar_id': '',
#              'html_url': 'https://github.com/arpit1912',
#              'id': 46648172,
#              'login': 'arpit1912',
#              'node_id': 'MDQ6VXNlcjQ2NjQ4MTcy',
#              'organizations_url': 'https://api.github.com/users/arpit1912/orgs',
#              'received_events_url': 'https://api.github.com/users/arpit1912/received_events',
#              'repos_url': 'https://api.github.com/users/arpit1912/repos',
#              'site_admin': False,
#              'starred_url': 'https://api.github.com/users/arpit1912/starred{/owner}{/repo}',
#              'subscriptions_url': 'https://api.github.com/users/arpit1912/subscriptions',
#              'type': 'User',
#              'url': 'https://api.github.com/users/arpit1912'},
#    'permissions': {'admin': False, 'pull': True, 'push': False},
#    'private': False,
#    'pulls_url': 'https://api.github.com/repos/arpit1912/book_review_panel/pulls{/number}',
#    'pushed_at': '2020-05-21T20:52:42Z',
#    'releases_url': 'https://api.github.com/repos/arpit1912/book_review_panel/releases{/id}',
#    'size': 6004,
#    'ssh_url': 'git@github.com:arpit1912/book_review_panel.git',
#    'stargazers_count': 0,
#    'stargazers_url': 'https://api.github.com/repos/arpit1912/book_review_panel/stargazers',
#    'statuses_url': 'https://api.github.com/repos/arpit1912/book_review_panel/statuses/{sha}',
#    'subscribers_url': 'https://api.github.com/repos/arpit1912/book_review_panel/subscribers',
#    'subscription_url': 'https://api.github.com/repos/arpit1912/book_review_panel/subscription',
#    'svn_url': 'https://github.com/arpit1912/book_review_panel',
#    'tags_url': 'https://api.github.com/repos/arpit1912/book_review_panel/tags',
#    'teams_url': 'https://api.github.com/repos/arpit1912/book_review_panel/teams',
#    'trees_url': 'https://api.github.com/repos/arpit1912/book_review_panel/git/trees{/sha}',
#    'updated_at': '2020-05-21T20:52:45Z',
#    'url': 'https://api.github.com/repos/arpit1912/book_review_panel',
#    'watchers': 0,
#    'watchers_count': 0},
#   {'archive_url': 'https://api.github.com/repos/arpit1912/CanteenApp_1/{archive_format}{/ref}',
#    'archived': False,
#    'assignees_url': 'https://api.github.com/repos/arpit1912/CanteenApp_1/assignees{/user}',
#    'blobs_url': 'https://api.github.com/repos/arpit1912/CanteenApp_1/git/blobs{/sha}',
#    'branches_url': 'https://api.github.com/repos/arpit1912/CanteenApp_1/branches{/branch}',
#    'clone_url': 'https://github.com/arpit1912/CanteenApp_1.git',
#    'collaborators_url': 'https://api.github.com/repos/arpit1912/CanteenApp_1/collaborators{/collaborator}',
#    'comments_url': 'https://api.github.com/repos/arpit1912/CanteenApp_1/comments{/number}',
#    'commits_url': 'https://api.github.com/repos/arpit1912/CanteenApp_1/commits{/sha}',
#    'compare_url': 'https://api.github.com/repos/arpit1912/CanteenApp_1/compare/{base}...{head}',
#    'contents_url': 'https://api.github.com/repos/arpit1912/CanteenApp_1/contents/{+path}',
#    'contributors_url': 'https://api.github.com/repos/arpit1912/CanteenApp_1/contributors',
#    'created_at': '2020-02-08T11:12:36Z',
#    'default_branch': 'master',
#    'deployments_url': 'https://api.github.com/repos/arpit1912/CanteenApp_1/deployments',
#    'description': 'CanteenApp on firebase.',
#    'disabled': False,
#    'downloads_url': 'https://api.github.com/repos/arpit1912/CanteenApp_1/downloads',
#    'events_url': 'https://api.github.com/repos/arpit1912/CanteenApp_1/events',
#    'fork': True,
#    'forks': 0,
#    'forks_count': 0,
#    'forks_url': 'https://api.github.com/repos/arpit1912/CanteenApp_1/forks',
#    'full_name': 'arpit1912/CanteenApp_1',
#    'git_commits_url': 'https://api.github.com/repos/arpit1912/CanteenApp_1/git/commits{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/arpit1912/CanteenApp_1/git/refs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/arpit1912/CanteenApp_1/git/tags{/sha}',
#    'git_url': 'git://github.com/arpit1912/CanteenApp_1.git',
#    'has_downloads': True,
#    'has_issues': False,
#    'has_pages': False,
#    'has_projects': True,
#    'has_wiki': True,
#    'homepage': None,
#    'hooks_url': 'https://api.github.com/repos/arpit1912/CanteenApp_1/hooks',
#    'html_url': 'https://github.com/arpit1912/CanteenApp_1',
#    'id': 239117407,
#    'issue_comment_url': 'https://api.github.com/repos/arpit1912/CanteenApp_1/issues/comments{/number}',
#    'issue_events_url': 'https://api.github.com/repos/arpit1912/CanteenApp_1/issues/events{/number}',
#    'issues_url': 'https://api.github.com/repos/arpit1912/CanteenApp_1/issues{/number}',
#    'keys_url': 'https://api.github.com/repos/arpit1912/CanteenApp_1/keys{/key_id}',
#    'labels_url': 'https://api.github.com/repos/arpit1912/CanteenApp_1/labels{/name}',
#    'language': None,
#    'languages_url': 'https://api.github.com/repos/arpit1912/CanteenApp_1/languages',
#    'license': None,
#    'merges_url': 'https://api.github.com/repos/arpit1912/CanteenApp_1/merges',
#    'milestones_url': 'https://api.github.com/repos/arpit1912/CanteenApp_1/milestones{/number}',
#    'mirror_url': None,
#    'name': 'CanteenApp_1',
#    'node_id': 'MDEwOlJlcG9zaXRvcnkyMzkxMTc0MDc=',
#    'notifications_url': 'https://api.github.com/repos/arpit1912/CanteenApp_1/notifications{?since,all,participating}',
#    'open_issues': 0,
#    'open_issues_count': 0,
#    'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/46648172?v=4',
#              'events_url': 'https://api.github.com/users/arpit1912/events{/privacy}',
#              'followers_url': 'https://api.github.com/users/arpit1912/followers',
#              'following_url': 'https://api.github.com/users/arpit1912/following{/other_user}',
#              'gists_url': 'https://api.github.com/users/arpit1912/gists{/gist_id}',
#              'gravatar_id': '',
#              'html_url': 'https://github.com/arpit1912',
#              'id': 46648172,
#              'login': 'arpit1912',
#              'node_id': 'MDQ6VXNlcjQ2NjQ4MTcy',
#              'organizations_url': 'https://api.github.com/users/arpit1912/orgs',
#              'received_events_url': 'https://api.github.com/users/arpit1912/received_events',
#              'repos_url': 'https://api.github.com/users/arpit1912/repos',
#              'site_admin': False,
#              'starred_url': 'https://api.github.com/users/arpit1912/starred{/owner}{/repo}',
#              'subscriptions_url': 'https://api.github.com/users/arpit1912/subscriptions',
#              'type': 'User',
#              'url': 'https://api.github.com/users/arpit1912'},
#    'permissions': {'admin': False, 'pull': True, 'push': False},
#    'private': False,
#    'pulls_url': 'https://api.github.com/repos/arpit1912/CanteenApp_1/pulls{/number}',
#    'pushed_at': '2020-02-04T17:52:11Z',
#    'releases_url': 'https://api.github.com/repos/arpit1912/CanteenApp_1/releases{/id}',
#    'size': 6155,
#    'ssh_url': 'git@github.com:arpit1912/CanteenApp_1.git',
#    'stargazers_count': 0,
#    'stargazers_url': 'https://api.github.com/repos/arpit1912/CanteenApp_1/stargazers',
#    'statuses_url': 'https://api.github.com/repos/arpit1912/CanteenApp_1/statuses/{sha}',
#    'subscribers_url': 'https://api.github.com/repos/arpit1912/CanteenApp_1/subscribers',
#    'subscription_url': 'https://api.github.com/repos/arpit1912/CanteenApp_1/subscription',
#    'svn_url': 'https://github.com/arpit1912/CanteenApp_1',
#    'tags_url': 'https://api.github.com/repos/arpit1912/CanteenApp_1/tags',
#    'teams_url': 'https://api.github.com/repos/arpit1912/CanteenApp_1/teams',
#    'trees_url': 'https://api.github.com/repos/arpit1912/CanteenApp_1/git/trees{/sha}',
#    'updated_at': '2020-02-08T11:12:38Z',
#    'url': 'https://api.github.com/repos/arpit1912/CanteenApp_1',
#    'watchers': 0,
#    'watchers_count': 0},
#   {'archive_url': 'https://api.github.com/repos/arpit1912/chip8-playzone/{archive_format}{/ref}',
#    'archived': False,
#    'assignees_url': 'https://api.github.com/repos/arpit1912/chip8-playzone/assignees{/user}',
#    'blobs_url': 'https://api.github.com/repos/arpit1912/chip8-playzone/git/blobs{/sha}',
#    'branches_url': 'https://api.github.com/repos/arpit1912/chip8-playzone/branches{/branch}',
#    'clone_url': 'https://github.com/arpit1912/chip8-playzone.git',
#    'collaborators_url': 'https://api.github.com/repos/arpit1912/chip8-playzone/collaborators{/collaborator}',
#    'comments_url': 'https://api.github.com/repos/arpit1912/chip8-playzone/comments{/number}',
#    'commits_url': 'https://api.github.com/repos/arpit1912/chip8-playzone/commits{/sha}',
#    'compare_url': 'https://api.github.com/repos/arpit1912/chip8-playzone/compare/{base}...{head}',
#    'contents_url': 'https://api.github.com/repos/arpit1912/chip8-playzone/contents/{+path}',
#    'contributors_url': 'https://api.github.com/repos/arpit1912/chip8-playzone/contributors',
#    'created_at': '2020-12-21T15:22:16Z',
#    'default_branch': 'main',
#    'deployments_url': 'https://api.github.com/repos/arpit1912/chip8-playzone/deployments',
#    'description': 'The aim of this project is to bring back the childhood '
#                   'games in our computers again!',
#    'disabled': False,
#    'downloads_url': 'https://api.github.com/repos/arpit1912/chip8-playzone/downloads',
#    'events_url': 'https://api.github.com/repos/arpit1912/chip8-playzone/events',
#    'fork': False,
#    'forks': 1,
#    'forks_count': 1,
#    'forks_url': 'https://api.github.com/repos/arpit1912/chip8-playzone/forks',
#    'full_name': 'arpit1912/chip8-playzone',
#    'git_commits_url': 'https://api.github.com/repos/arpit1912/chip8-playzone/git/commits{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/arpit1912/chip8-playzone/git/refs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/arpit1912/chip8-playzone/git/tags{/sha}',
#    'git_url': 'git://github.com/arpit1912/chip8-playzone.git',
#    'has_downloads': True,
#    'has_issues': True,
#    'has_pages': False,
#    'has_projects': True,
#    'has_wiki': True,
#    'homepage': '',
#    'hooks_url': 'https://api.github.com/repos/arpit1912/chip8-playzone/hooks',
#    'html_url': 'https://github.com/arpit1912/chip8-playzone',
#    'id': 323373819,
#    'issue_comment_url': 'https://api.github.com/repos/arpit1912/chip8-playzone/issues/comments{/number}',
#    'issue_events_url': 'https://api.github.com/repos/arpit1912/chip8-playzone/issues/events{/number}',
#    'issues_url': 'https://api.github.com/repos/arpit1912/chip8-playzone/issues{/number}',
#    'keys_url': 'https://api.github.com/repos/arpit1912/chip8-playzone/keys{/key_id}',
#    'labels_url': 'https://api.github.com/repos/arpit1912/chip8-playzone/labels{/name}',
#    'language': 'C++',
#    'languages_url': 'https://api.github.com/repos/arpit1912/chip8-playzone/languages',
#    'license': None,
#    'merges_url': 'https://api.github.com/repos/arpit1912/chip8-playzone/merges',
#    'milestones_url': 'https://api.github.com/repos/arpit1912/chip8-playzone/milestones{/number}',
#    'mirror_url': None,
#    'name': 'chip8-playzone',
#    'node_id': 'MDEwOlJlcG9zaXRvcnkzMjMzNzM4MTk=',
#    'notifications_url': 'https://api.github.com/repos/arpit1912/chip8-playzone/notifications{?since,all,participating}',
#    'open_issues': 1,
#    'open_issues_count': 1,
#    'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/46648172?v=4',
#              'events_url': 'https://api.github.com/users/arpit1912/events{/privacy}',
#              'followers_url': 'https://api.github.com/users/arpit1912/followers',
#              'following_url': 'https://api.github.com/users/arpit1912/following{/other_user}',
#              'gists_url': 'https://api.github.com/users/arpit1912/gists{/gist_id}',
#              'gravatar_id': '',
#              'html_url': 'https://github.com/arpit1912',
#              'id': 46648172,
#              'login': 'arpit1912',
#              'node_id': 'MDQ6VXNlcjQ2NjQ4MTcy',
#              'organizations_url': 'https://api.github.com/users/arpit1912/orgs',
#              'received_events_url': 'https://api.github.com/users/arpit1912/received_events',
#              'repos_url': 'https://api.github.com/users/arpit1912/repos',
#              'site_admin': False,
#              'starred_url': 'https://api.github.com/users/arpit1912/starred{/owner}{/repo}',
#              'subscriptions_url': 'https://api.github.com/users/arpit1912/subscriptions',
#              'type': 'User',
#              'url': 'https://api.github.com/users/arpit1912'},
#    'permissions': {'admin': False, 'pull': True, 'push': False},
#    'private': False,
#    'pulls_url': 'https://api.github.com/repos/arpit1912/chip8-playzone/pulls{/number}',
#    'pushed_at': '2021-01-09T07:48:14Z',
#    'releases_url': 'https://api.github.com/repos/arpit1912/chip8-playzone/releases{/id}',
#    'size': 35,
#    'ssh_url': 'git@github.com:arpit1912/chip8-playzone.git',
#    'stargazers_count': 2,
#    'stargazers_url': 'https://api.github.com/repos/arpit1912/chip8-playzone/stargazers',
#    'statuses_url': 'https://api.github.com/repos/arpit1912/chip8-playzone/statuses/{sha}',
#    'subscribers_url': 'https://api.github.com/repos/arpit1912/chip8-playzone/subscribers',
#    'subscription_url': 'https://api.github.com/repos/arpit1912/chip8-playzone/subscription',
#    'svn_url': 'https://github.com/arpit1912/chip8-playzone',
#    'tags_url': 'https://api.github.com/repos/arpit1912/chip8-playzone/tags',
#    'teams_url': 'https://api.github.com/repos/arpit1912/chip8-playzone/teams',
#    'trees_url': 'https://api.github.com/repos/arpit1912/chip8-playzone/git/trees{/sha}',
#    'updated_at': '2021-01-09T07:48:16Z',
#    'url': 'https://api.github.com/repos/arpit1912/chip8-playzone',
#    'watchers': 2,
#    'watchers_count': 2},
#   {'archive_url': 'https://api.github.com/repos/arpit1912/competitive-data-science/{archive_format}{/ref}',
#    'archived': False,
#    'assignees_url': 'https://api.github.com/repos/arpit1912/competitive-data-science/assignees{/user}',
#    'blobs_url': 'https://api.github.com/repos/arpit1912/competitive-data-science/git/blobs{/sha}',
#    'branches_url': 'https://api.github.com/repos/arpit1912/competitive-data-science/branches{/branch}',
#    'clone_url': 'https://github.com/arpit1912/competitive-data-science.git',
#    'collaborators_url': 'https://api.github.com/repos/arpit1912/competitive-data-science/collaborators{/collaborator}',
#    'comments_url': 'https://api.github.com/repos/arpit1912/competitive-data-science/comments{/number}',
#    'commits_url': 'https://api.github.com/repos/arpit1912/competitive-data-science/commits{/sha}',
#    'compare_url': 'https://api.github.com/repos/arpit1912/competitive-data-science/compare/{base}...{head}',
#    'contents_url': 'https://api.github.com/repos/arpit1912/competitive-data-science/contents/{+path}',
#    'contributors_url': 'https://api.github.com/repos/arpit1912/competitive-data-science/contributors',
#    'created_at': '2020-06-05T18:34:46Z',
#    'default_branch': 'master',
#    'deployments_url': 'https://api.github.com/repos/arpit1912/competitive-data-science/deployments',
#    'description': 'Materials for "How to Win a Data Science Competition: Learn '
#                   'from Top Kagglers" course',
#    'disabled': False,
#    'downloads_url': 'https://api.github.com/repos/arpit1912/competitive-data-science/downloads',
#    'events_url': 'https://api.github.com/repos/arpit1912/competitive-data-science/events',
#    'fork': True,
#    'forks': 0,
#    'forks_count': 0,
#    'forks_url': 'https://api.github.com/repos/arpit1912/competitive-data-science/forks',
#    'full_name': 'arpit1912/competitive-data-science',
#    'git_commits_url': 'https://api.github.com/repos/arpit1912/competitive-data-science/git/commits{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/arpit1912/competitive-data-science/git/refs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/arpit1912/competitive-data-science/git/tags{/sha}',
#    'git_url': 'git://github.com/arpit1912/competitive-data-science.git',
#    'has_downloads': True,
#    'has_issues': False,
#    'has_pages': False,
#    'has_projects': True,
#    'has_wiki': True,
#    'homepage': 'https://www.coursera.org/learn/competitive-data-science',
#    'hooks_url': 'https://api.github.com/repos/arpit1912/competitive-data-science/hooks',
#    'html_url': 'https://github.com/arpit1912/competitive-data-science',
#    'id': 269738513,
#    'issue_comment_url': 'https://api.github.com/repos/arpit1912/competitive-data-science/issues/comments{/number}',
#    'issue_events_url': 'https://api.github.com/repos/arpit1912/competitive-data-science/issues/events{/number}',
#    'issues_url': 'https://api.github.com/repos/arpit1912/competitive-data-science/issues{/number}',
#    'keys_url': 'https://api.github.com/repos/arpit1912/competitive-data-science/keys{/key_id}',
#    'labels_url': 'https://api.github.com/repos/arpit1912/competitive-data-science/labels{/name}',
#    'language': None,
#    'languages_url': 'https://api.github.com/repos/arpit1912/competitive-data-science/languages',
#    'license': None,
#    'merges_url': 'https://api.github.com/repos/arpit1912/competitive-data-science/merges',
#    'milestones_url': 'https://api.github.com/repos/arpit1912/competitive-data-science/milestones{/number}',
#    'mirror_url': None,
#    'name': 'competitive-data-science',
#    'node_id': 'MDEwOlJlcG9zaXRvcnkyNjk3Mzg1MTM=',
#    'notifications_url': 'https://api.github.com/repos/arpit1912/competitive-data-science/notifications{?since,all,participating}',
#    'open_issues': 0,
#    'open_issues_count': 0,
#    'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/46648172?v=4',
#              'events_url': 'https://api.github.com/users/arpit1912/events{/privacy}',
#              'followers_url': 'https://api.github.com/users/arpit1912/followers',
#              'following_url': 'https://api.github.com/users/arpit1912/following{/other_user}',
#              'gists_url': 'https://api.github.com/users/arpit1912/gists{/gist_id}',
#              'gravatar_id': '',
#              'html_url': 'https://github.com/arpit1912',
#              'id': 46648172,
#              'login': 'arpit1912',
#              'node_id': 'MDQ6VXNlcjQ2NjQ4MTcy',
#              'organizations_url': 'https://api.github.com/users/arpit1912/orgs',
#              'received_events_url': 'https://api.github.com/users/arpit1912/received_events',
#              'repos_url': 'https://api.github.com/users/arpit1912/repos',
#              'site_admin': False,
#              'starred_url': 'https://api.github.com/users/arpit1912/starred{/owner}{/repo}',
#              'subscriptions_url': 'https://api.github.com/users/arpit1912/subscriptions',
#              'type': 'User',
#              'url': 'https://api.github.com/users/arpit1912'},
#    'permissions': {'admin': False, 'pull': True, 'push': False},
#    'private': False,
#    'pulls_url': 'https://api.github.com/repos/arpit1912/competitive-data-science/pulls{/number}',
#    'pushed_at': '2019-10-09T02:55:06Z',
#    'releases_url': 'https://api.github.com/repos/arpit1912/competitive-data-science/releases{/id}',
#    'size': 6428,
#    'ssh_url': 'git@github.com:arpit1912/competitive-data-science.git',
#    'stargazers_count': 0,
#    'stargazers_url': 'https://api.github.com/repos/arpit1912/competitive-data-science/stargazers',
#    'statuses_url': 'https://api.github.com/repos/arpit1912/competitive-data-science/statuses/{sha}',
#    'subscribers_url': 'https://api.github.com/repos/arpit1912/competitive-data-science/subscribers',
#    'subscription_url': 'https://api.github.com/repos/arpit1912/competitive-data-science/subscription',
#    'svn_url': 'https://github.com/arpit1912/competitive-data-science',
#    'tags_url': 'https://api.github.com/repos/arpit1912/competitive-data-science/tags',
#    'teams_url': 'https://api.github.com/repos/arpit1912/competitive-data-science/teams',
#    'trees_url': 'https://api.github.com/repos/arpit1912/competitive-data-science/git/trees{/sha}',
#    'updated_at': '2020-06-05T18:34:47Z',
#    'url': 'https://api.github.com/repos/arpit1912/competitive-data-science',
#    'watchers': 0,
#    'watchers_count': 0},
#   {'archive_url': 'https://api.github.com/repos/arpit1912/CO_simulator/{archive_format}{/ref}',
#    'archived': False,
#    'assignees_url': 'https://api.github.com/repos/arpit1912/CO_simulator/assignees{/user}',
#    'blobs_url': 'https://api.github.com/repos/arpit1912/CO_simulator/git/blobs{/sha}',
#    'branches_url': 'https://api.github.com/repos/arpit1912/CO_simulator/branches{/branch}',
#    'clone_url': 'https://github.com/arpit1912/CO_simulator.git',
#    'collaborators_url': 'https://api.github.com/repos/arpit1912/CO_simulator/collaborators{/collaborator}',
#    'comments_url': 'https://api.github.com/repos/arpit1912/CO_simulator/comments{/number}',
#    'commits_url': 'https://api.github.com/repos/arpit1912/CO_simulator/commits{/sha}',
#    'compare_url': 'https://api.github.com/repos/arpit1912/CO_simulator/compare/{base}...{head}',
#    'contents_url': 'https://api.github.com/repos/arpit1912/CO_simulator/contents/{+path}',
#    'contributors_url': 'https://api.github.com/repos/arpit1912/CO_simulator/contributors',
#    'created_at': '2020-02-16T10:16:36Z',
#    'default_branch': 'master',
#    'deployments_url': 'https://api.github.com/repos/arpit1912/CO_simulator/deployments',
#    'description': None,
#    'disabled': False,
#    'downloads_url': 'https://api.github.com/repos/arpit1912/CO_simulator/downloads',
#    'events_url': 'https://api.github.com/repos/arpit1912/CO_simulator/events',
#    'fork': False,
#    'forks': 0,
#    'forks_count': 0,
#    'forks_url': 'https://api.github.com/repos/arpit1912/CO_simulator/forks',
#    'full_name': 'arpit1912/CO_simulator',
#    'git_commits_url': 'https://api.github.com/repos/arpit1912/CO_simulator/git/commits{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/arpit1912/CO_simulator/git/refs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/arpit1912/CO_simulator/git/tags{/sha}',
#    'git_url': 'git://github.com/arpit1912/CO_simulator.git',
#    'has_downloads': True,
#    'has_issues': True,
#    'has_pages': False,
#    'has_projects': True,
#    'has_wiki': True,
#    'homepage': None,
#    'hooks_url': 'https://api.github.com/repos/arpit1912/CO_simulator/hooks',
#    'html_url': 'https://github.com/arpit1912/CO_simulator',
#    'id': 240870387,
#    'issue_comment_url': 'https://api.github.com/repos/arpit1912/CO_simulator/issues/comments{/number}',
#    'issue_events_url': 'https://api.github.com/repos/arpit1912/CO_simulator/issues/events{/number}',
#    'issues_url': 'https://api.github.com/repos/arpit1912/CO_simulator/issues{/number}',
#    'keys_url': 'https://api.github.com/repos/arpit1912/CO_simulator/keys{/key_id}',
#    'labels_url': 'https://api.github.com/repos/arpit1912/CO_simulator/labels{/name}',
#    'language': 'Python',
#    'languages_url': 'https://api.github.com/repos/arpit1912/CO_simulator/languages',
#    'license': None,
#    'merges_url': 'https://api.github.com/repos/arpit1912/CO_simulator/merges',
#    'milestones_url': 'https://api.github.com/repos/arpit1912/CO_simulator/milestones{/number}',
#    'mirror_url': None,
#    'name': 'CO_simulator',
#    'node_id': 'MDEwOlJlcG9zaXRvcnkyNDA4NzAzODc=',
#    'notifications_url': 'https://api.github.com/repos/arpit1912/CO_simulator/notifications{?since,all,participating}',
#    'open_issues': 1,
#    'open_issues_count': 1,
#    'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/46648172?v=4',
#              'events_url': 'https://api.github.com/users/arpit1912/events{/privacy}',
#              'followers_url': 'https://api.github.com/users/arpit1912/followers',
#              'following_url': 'https://api.github.com/users/arpit1912/following{/other_user}',
#              'gists_url': 'https://api.github.com/users/arpit1912/gists{/gist_id}',
#              'gravatar_id': '',
#              'html_url': 'https://github.com/arpit1912',
#              'id': 46648172,
#              'login': 'arpit1912',
#              'node_id': 'MDQ6VXNlcjQ2NjQ4MTcy',
#              'organizations_url': 'https://api.github.com/users/arpit1912/orgs',
#              'received_events_url': 'https://api.github.com/users/arpit1912/received_events',
#              'repos_url': 'https://api.github.com/users/arpit1912/repos',
#              'site_admin': False,
#              'starred_url': 'https://api.github.com/users/arpit1912/starred{/owner}{/repo}',
#              'subscriptions_url': 'https://api.github.com/users/arpit1912/subscriptions',
#              'type': 'User',
#              'url': 'https://api.github.com/users/arpit1912'},
#    'permissions': {'admin': False, 'pull': True, 'push': False},
#    'private': False,
#    'pulls_url': 'https://api.github.com/repos/arpit1912/CO_simulator/pulls{/number}',
#    'pushed_at': '2020-05-08T14:28:31Z',
#    'releases_url': 'https://api.github.com/repos/arpit1912/CO_simulator/releases{/id}',
#    'size': 39,
#    'ssh_url': 'git@github.com:arpit1912/CO_simulator.git',
#    'stargazers_count': 0,
#    'stargazers_url': 'https://api.github.com/repos/arpit1912/CO_simulator/stargazers',
#    'statuses_url': 'https://api.github.com/repos/arpit1912/CO_simulator/statuses/{sha}',
#    'subscribers_url': 'https://api.github.com/repos/arpit1912/CO_simulator/subscribers',
#    'subscription_url': 'https://api.github.com/repos/arpit1912/CO_simulator/subscription',
#    'svn_url': 'https://github.com/arpit1912/CO_simulator',
#    'tags_url': 'https://api.github.com/repos/arpit1912/CO_simulator/tags',
#    'teams_url': 'https://api.github.com/repos/arpit1912/CO_simulator/teams',
#    'trees_url': 'https://api.github.com/repos/arpit1912/CO_simulator/git/trees{/sha}',
#    'updated_at': '2020-05-19T19:11:15Z',
#    'url': 'https://api.github.com/repos/arpit1912/CO_simulator',
#    'watchers': 0,
#    'watchers_count': 0},
#   {'archive_url': 'https://api.github.com/repos/arpit1912/deep-learning-specialization-coursera/{archive_format}{/ref}',
#    'archived': True,
#    'assignees_url': 'https://api.github.com/repos/arpit1912/deep-learning-specialization-coursera/assignees{/user}',
#    'blobs_url': 'https://api.github.com/repos/arpit1912/deep-learning-specialization-coursera/git/blobs{/sha}',
# ...
#    'commits_url': 'https://api.github.com/repos/sam3926/hello-world/commits{/sha}',
#    'compare_url': 'https://api.github.com/repos/sam3926/hello-world/compare/{base}...{head}',
#    'contents_url': 'https://api.github.com/repos/sam3926/hello-world/contents/{+path}',
#    'contributors_url': 'https://api.github.com/repos/sam3926/hello-world/contributors',
#    'created_at': '2019-09-06T07:07:53Z',
#    'default_branch': 'master',
#    'deployments_url': 'https://api.github.com/repos/sam3926/hello-world/deployments',
#    'description': None,
#    'disabled': False,
#    'downloads_url': 'https://api.github.com/repos/sam3926/hello-world/downloads',
#    'events_url': 'https://api.github.com/repos/sam3926/hello-world/events',
#    'fork': False,
#    'forks': 0,
#    'forks_count': 0,
#    'forks_url': 'https://api.github.com/repos/sam3926/hello-world/forks',
#    'full_name': 'sam3926/hello-world',
#    'git_commits_url': 'https://api.github.com/repos/sam3926/hello-world/git/commits{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/sam3926/hello-world/git/refs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/sam3926/hello-world/git/tags{/sha}',
#    'git_url': 'git://github.com/sam3926/hello-world.git',
#    'has_downloads': True,
#    'has_issues': True,
#    'has_pages': False,
#    'has_projects': True,
#    'has_wiki': True,
#    'homepage': None,
#    'hooks_url': 'https://api.github.com/repos/sam3926/hello-world/hooks',
#    'html_url': 'https://github.com/sam3926/hello-world',
#    'id': 206734530,
#    'issue_comment_url': 'https://api.github.com/repos/sam3926/hello-world/issues/comments{/number}',
#    'issue_events_url': 'https://api.github.com/repos/sam3926/hello-world/issues/events{/number}',
#    'issues_url': 'https://api.github.com/repos/sam3926/hello-world/issues{/number}',
#    'keys_url': 'https://api.github.com/repos/sam3926/hello-world/keys{/key_id}',
#    'labels_url': 'https://api.github.com/repos/sam3926/hello-world/labels{/name}',
#    'language': 'HTML',
#    'languages_url': 'https://api.github.com/repos/sam3926/hello-world/languages',
#    'license': None,
#    'merges_url': 'https://api.github.com/repos/sam3926/hello-world/merges',
#    'milestones_url': 'https://api.github.com/repos/sam3926/hello-world/milestones{/number}',
#    'mirror_url': None,
#    'name': 'hello-world',
#    'node_id': 'MDEwOlJlcG9zaXRvcnkyMDY3MzQ1MzA=',
#    'notifications_url': 'https://api.github.com/repos/sam3926/hello-world/notifications{?since,all,participating}',
#    'open_issues': 0,
#    'open_issues_count': 0,
#    'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/54976429?v=4',
#              'events_url': 'https://api.github.com/users/sam3926/events{/privacy}',
#              'followers_url': 'https://api.github.com/users/sam3926/followers',
#              'following_url': 'https://api.github.com/users/sam3926/following{/other_user}',
#              'gists_url': 'https://api.github.com/users/sam3926/gists{/gist_id}',
#              'gravatar_id': '',
#              'html_url': 'https://github.com/sam3926',
#              'id': 54976429,
#              'login': 'sam3926',
#              'node_id': 'MDQ6VXNlcjU0OTc2NDI5',
#              'organizations_url': 'https://api.github.com/users/sam3926/orgs',
#              'received_events_url': 'https://api.github.com/users/sam3926/received_events',
#              'repos_url': 'https://api.github.com/users/sam3926/repos',
#              'site_admin': False,
#              'starred_url': 'https://api.github.com/users/sam3926/starred{/owner}{/repo}',
#              'subscriptions_url': 'https://api.github.com/users/sam3926/subscriptions',
#              'type': 'User',
#              'url': 'https://api.github.com/users/sam3926'},
#    'permissions': {'admin': True, 'pull': True, 'push': True},
#    'private': False,
#    'pulls_url': 'https://api.github.com/repos/sam3926/hello-world/pulls{/number}',
#    'pushed_at': '2019-09-06T07:07:55Z',
#    'releases_url': 'https://api.github.com/repos/sam3926/hello-world/releases{/id}',
#    'size': 257,
#    'ssh_url': 'git@github.com:sam3926/hello-world.git',
#    'stargazers_count': 0,
#    'stargazers_url': 'https://api.github.com/repos/sam3926/hello-world/stargazers',
#    'statuses_url': 'https://api.github.com/repos/sam3926/hello-world/statuses/{sha}',
#    'subscribers_url': 'https://api.github.com/repos/sam3926/hello-world/subscribers',
#    'subscription_url': 'https://api.github.com/repos/sam3926/hello-world/subscription',
#    'svn_url': 'https://github.com/sam3926/hello-world',
#    'tags_url': 'https://api.github.com/repos/sam3926/hello-world/tags',
#    'teams_url': 'https://api.github.com/repos/sam3926/hello-world/teams',
#    'trees_url': 'https://api.github.com/repos/sam3926/hello-world/git/trees{/sha}',
#    'updated_at': '2019-09-06T07:07:57Z',
#    'url': 'https://api.github.com/repos/sam3926/hello-world',
#    'watchers': 0,
#    'watchers_count': 0},
#   {'archive_url': 'https://api.github.com/repos/sam3926/RepoSummariser/{archive_format}{/ref}',
#    'archived': False,
#    'assignees_url': 'https://api.github.com/repos/sam3926/RepoSummariser/assignees{/user}',
#    'blobs_url': 'https://api.github.com/repos/sam3926/RepoSummariser/git/blobs{/sha}',
#    'branches_url': 'https://api.github.com/repos/sam3926/RepoSummariser/branches{/branch}',
#    'clone_url': 'https://github.com/sam3926/RepoSummariser.git',
#    'collaborators_url': 'https://api.github.com/repos/sam3926/RepoSummariser/collaborators{/collaborator}',
#    'comments_url': 'https://api.github.com/repos/sam3926/RepoSummariser/comments{/number}',
#    'commits_url': 'https://api.github.com/repos/sam3926/RepoSummariser/commits{/sha}',
#    'compare_url': 'https://api.github.com/repos/sam3926/RepoSummariser/compare/{base}...{head}',
#    'contents_url': 'https://api.github.com/repos/sam3926/RepoSummariser/contents/{+path}',
#    'contributors_url': 'https://api.github.com/repos/sam3926/RepoSummariser/contributors',
#    'created_at': '2021-02-24T05:33:52Z',
#    'default_branch': 'main',
#    'deployments_url': 'https://api.github.com/repos/sam3926/RepoSummariser/deployments',
#    'description': 'A tool to help the Developers to get gist of the Repo.',
#    'disabled': False,
#    'downloads_url': 'https://api.github.com/repos/sam3926/RepoSummariser/downloads',
#    'events_url': 'https://api.github.com/repos/sam3926/RepoSummariser/events',
#    'fork': True,
#    'forks': 0,
#    'forks_count': 0,
#    'forks_url': 'https://api.github.com/repos/sam3926/RepoSummariser/forks',
#    'full_name': 'sam3926/RepoSummariser',
#    'git_commits_url': 'https://api.github.com/repos/sam3926/RepoSummariser/git/commits{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/sam3926/RepoSummariser/git/refs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/sam3926/RepoSummariser/git/tags{/sha}',
#    'git_url': 'git://github.com/sam3926/RepoSummariser.git',
#    'has_downloads': True,
#    'has_issues': False,
#    'has_pages': False,
#    'has_projects': True,
#    'has_wiki': True,
#    'homepage': None,
#    'hooks_url': 'https://api.github.com/repos/sam3926/RepoSummariser/hooks',
#    'html_url': 'https://github.com/sam3926/RepoSummariser',
#    'id': 341790537,
#    'issue_comment_url': 'https://api.github.com/repos/sam3926/RepoSummariser/issues/comments{/number}',
#    'issue_events_url': 'https://api.github.com/repos/sam3926/RepoSummariser/issues/events{/number}',
#    'issues_url': 'https://api.github.com/repos/sam3926/RepoSummariser/issues{/number}',
#    'keys_url': 'https://api.github.com/repos/sam3926/RepoSummariser/keys{/key_id}',
#    'labels_url': 'https://api.github.com/repos/sam3926/RepoSummariser/labels{/name}',
#    'language': None,
#    'languages_url': 'https://api.github.com/repos/sam3926/RepoSummariser/languages',
#    'license': None,
#    'merges_url': 'https://api.github.com/repos/sam3926/RepoSummariser/merges',
#    'milestones_url': 'https://api.github.com/repos/sam3926/RepoSummariser/milestones{/number}',
#    'mirror_url': None,
#    'name': 'RepoSummariser',
#    'node_id': 'MDEwOlJlcG9zaXRvcnkzNDE3OTA1Mzc=',
#    'notifications_url': 'https://api.github.com/repos/sam3926/RepoSummariser/notifications{?since,all,participating}',
#    'open_issues': 0,
#    'open_issues_count': 0,
#    'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/54976429?v=4',
#              'events_url': 'https://api.github.com/users/sam3926/events{/privacy}',
#              'followers_url': 'https://api.github.com/users/sam3926/followers',
#              'following_url': 'https://api.github.com/users/sam3926/following{/other_user}',
#              'gists_url': 'https://api.github.com/users/sam3926/gists{/gist_id}',
#              'gravatar_id': '',
#              'html_url': 'https://github.com/sam3926',
#              'id': 54976429,
#              'login': 'sam3926',
#              'node_id': 'MDQ6VXNlcjU0OTc2NDI5',
#              'organizations_url': 'https://api.github.com/users/sam3926/orgs',
#              'received_events_url': 'https://api.github.com/users/sam3926/received_events',
#              'repos_url': 'https://api.github.com/users/sam3926/repos',
#              'site_admin': False,
#              'starred_url': 'https://api.github.com/users/sam3926/starred{/owner}{/repo}',
#              'subscriptions_url': 'https://api.github.com/users/sam3926/subscriptions',
#              'type': 'User',
#              'url': 'https://api.github.com/users/sam3926'},
#    'permissions': {'admin': True, 'pull': True, 'push': True},
#    'private': False,
#    'pulls_url': 'https://api.github.com/repos/sam3926/RepoSummariser/pulls{/number}',
#    'pushed_at': '2021-02-24T06:13:59Z',
#    'releases_url': 'https://api.github.com/repos/sam3926/RepoSummariser/releases{/id}',
#    'size': 5,
#    'ssh_url': 'git@github.com:sam3926/RepoSummariser.git',
#    'stargazers_count': 0,
#    'stargazers_url': 'https://api.github.com/repos/sam3926/RepoSummariser/stargazers',
#    'statuses_url': 'https://api.github.com/repos/sam3926/RepoSummariser/statuses/{sha}',
#    'subscribers_url': 'https://api.github.com/repos/sam3926/RepoSummariser/subscribers',
#    'subscription_url': 'https://api.github.com/repos/sam3926/RepoSummariser/subscription',
#    'svn_url': 'https://github.com/sam3926/RepoSummariser',
#    'tags_url': 'https://api.github.com/repos/sam3926/RepoSummariser/tags',
#    'teams_url': 'https://api.github.com/repos/sam3926/RepoSummariser/teams',
#    'trees_url': 'https://api.github.com/repos/sam3926/RepoSummariser/git/trees{/sha}',
#    'updated_at': '2021-02-24T06:14:00Z',
#    'url': 'https://api.github.com/repos/sam3926/RepoSummariser',
#    'watchers': 0,
#    'watchers_count': 0},
#   {'archive_url': 'https://api.github.com/repos/sam3926/SE-gamedev/{archive_format}{/ref}',
#    'archived': False,
#    'assignees_url': 'https://api.github.com/repos/sam3926/SE-gamedev/assignees{/user}',
#    'blobs_url': 'https://api.github.com/repos/sam3926/SE-gamedev/git/blobs{/sha}',
#    'branches_url': 'https://api.github.com/repos/sam3926/SE-gamedev/branches{/branch}',
#    'clone_url': 'https://github.com/sam3926/SE-gamedev.git',
#    'collaborators_url': 'https://api.github.com/repos/sam3926/SE-gamedev/collaborators{/collaborator}',
#    'comments_url': 'https://api.github.com/repos/sam3926/SE-gamedev/comments{/number}',
#    'commits_url': 'https://api.github.com/repos/sam3926/SE-gamedev/commits{/sha}',
#    'compare_url': 'https://api.github.com/repos/sam3926/SE-gamedev/compare/{base}...{head}',
#    'contents_url': 'https://api.github.com/repos/sam3926/SE-gamedev/contents/{+path}',
#    'contributors_url': 'https://api.github.com/repos/sam3926/SE-gamedev/contributors',
#    'created_at': '2021-01-27T19:11:12Z',
#    'default_branch': 'main',
#    'deployments_url': 'https://api.github.com/repos/sam3926/SE-gamedev/deployments',
#    'description': 'Game development for the Software Engineering LAB',
#    'disabled': False,
#    'downloads_url': 'https://api.github.com/repos/sam3926/SE-gamedev/downloads',
#    'events_url': 'https://api.github.com/repos/sam3926/SE-gamedev/events',
#    'fork': True,
#    'forks': 0,
#    'forks_count': 0,
#    'forks_url': 'https://api.github.com/repos/sam3926/SE-gamedev/forks',
#    'full_name': 'sam3926/SE-gamedev',
#    'git_commits_url': 'https://api.github.com/repos/sam3926/SE-gamedev/git/commits{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/sam3926/SE-gamedev/git/refs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/sam3926/SE-gamedev/git/tags{/sha}',
#    'git_url': 'git://github.com/sam3926/SE-gamedev.git',
#    'has_downloads': True,
#    'has_issues': False,
#    'has_pages': False,
#    'has_projects': True,
#    'has_wiki': True,
#    'homepage': None,
#    'hooks_url': 'https://api.github.com/repos/sam3926/SE-gamedev/hooks',
#    'html_url': 'https://github.com/sam3926/SE-gamedev',
#    'id': 333532671,
#    'issue_comment_url': 'https://api.github.com/repos/sam3926/SE-gamedev/issues/comments{/number}',
#    'issue_events_url': 'https://api.github.com/repos/sam3926/SE-gamedev/issues/events{/number}',
#    'issues_url': 'https://api.github.com/repos/sam3926/SE-gamedev/issues{/number}',
#    'keys_url': 'https://api.github.com/repos/sam3926/SE-gamedev/keys{/key_id}',
#    'labels_url': 'https://api.github.com/repos/sam3926/SE-gamedev/labels{/name}',
#    'language': 'C#',
#    'languages_url': 'https://api.github.com/repos/sam3926/SE-gamedev/languages',
#    'license': None,
#    'merges_url': 'https://api.github.com/repos/sam3926/SE-gamedev/merges',
#    'milestones_url': 'https://api.github.com/repos/sam3926/SE-gamedev/milestones{/number}',
#    'mirror_url': None,
#    'name': 'SE-gamedev',
#    'node_id': 'MDEwOlJlcG9zaXRvcnkzMzM1MzI2NzE=',
#    'notifications_url': 'https://api.github.com/repos/sam3926/SE-gamedev/notifications{?since,all,participating}',
#    'open_issues': 0,
#    'open_issues_count': 0,
#    'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/54976429?v=4',
#              'events_url': 'https://api.github.com/users/sam3926/events{/privacy}',
#              'followers_url': 'https://api.github.com/users/sam3926/followers',
#              'following_url': 'https://api.github.com/users/sam3926/following{/other_user}',
#              'gists_url': 'https://api.github.com/users/sam3926/gists{/gist_id}',
#              'gravatar_id': '',
#              'html_url': 'https://github.com/sam3926',
#              'id': 54976429,
#              'login': 'sam3926',
#              'node_id': 'MDQ6VXNlcjU0OTc2NDI5',
#              'organizations_url': 'https://api.github.com/users/sam3926/orgs',
#              'received_events_url': 'https://api.github.com/users/sam3926/received_events',
#              'repos_url': 'https://api.github.com/users/sam3926/repos',
#              'site_admin': False,
#              'starred_url': 'https://api.github.com/users/sam3926/starred{/owner}{/repo}',
#              'subscriptions_url': 'https://api.github.com/users/sam3926/subscriptions',
#              'type': 'User',
#              'url': 'https://api.github.com/users/sam3926'},
#    'permissions': {'admin': True, 'pull': True, 'push': True},
#    'private': False,
#    'pulls_url': 'https://api.github.com/repos/sam3926/SE-gamedev/pulls{/number}',
#    'pushed_at': '2021-02-07T16:31:37Z',
#    'releases_url': 'https://api.github.com/repos/sam3926/SE-gamedev/releases{/id}',
#    'size': 2255,
#    'ssh_url': 'git@github.com:sam3926/SE-gamedev.git',
#    'stargazers_count': 0,
#    'stargazers_url': 'https://api.github.com/repos/sam3926/SE-gamedev/stargazers',
#    'statuses_url': 'https://api.github.com/repos/sam3926/SE-gamedev/statuses/{sha}',
#    'subscribers_url': 'https://api.github.com/repos/sam3926/SE-gamedev/subscribers',
#    'subscription_url': 'https://api.github.com/repos/sam3926/SE-gamedev/subscription',
#    'svn_url': 'https://github.com/sam3926/SE-gamedev',
#    'tags_url': 'https://api.github.com/repos/sam3926/SE-gamedev/tags',
#    'teams_url': 'https://api.github.com/repos/sam3926/SE-gamedev/teams',
#    'trees_url': 'https://api.github.com/repos/sam3926/SE-gamedev/git/trees{/sha}',
#    'updated_at': '2021-02-07T16:31:40Z',
#    'url': 'https://api.github.com/repos/sam3926/SE-gamedev',
#    'watchers': 0,
#    'watchers_count': 0}]]

# %%
# Filter the Repos Based on the Number of Contributors and Find the Parent Repo name as well if exist

filtered_repo_names = []

for user_repos in json_data:
    temp_repo_list = []
    for repo in user_repos:
        #print(repo['full_name'])
        if repo['fork'] is True:
            owner,repo = repo['full_name'].split("/")
            original_repo_data = repo_details(owner,repo,token)
            if original_repo_data.get('source') != None:
                print(original_repo_data['source']['full_name'])
                main_owner,main_repo = original_repo_data['source']['full_name'].split("/")
                original_repo_contribution_data = get_contributions_list(main_owner,main_repo,token)
                total, user = calculated_contribution(owner,original_repo_contribution_data)
                if(user > 0):
                    temp_repo_list.append(repo)
                    print(total, user)
            #pprint(original_repo_data)
            # do something
        else:
            print(repo['contributors_url'])
            
    filtered_repo_names.append(temp_repo_list)
#'Link': '<https://api.github.com/repositories/40687563/contributors?page=2&per_page=10000&state=open>; rel="next", <https://api.github.com/repositories/40687563/contributors?page=4&per_page=10000&state=open>; rel="last"'
# Out:
# https://api.github.com/repos/arpit1912/AlwaysHigh_Smart_traffic_management_Hack_2020_IITT/contributors
# atom/atom
# 25720 0
# https://api.github.com/repos/arpit1912/atom_project/contributors
# https://api.github.com/repos/arpit1912/book_review_panel/contributors
# Prakash-sa/CanteenApp_1
# 73 0
# https://api.github.com/repos/arpit1912/chip8-playzone/contributors
# hse-aml/competitive-data-science
# 28 0
# https://api.github.com/repos/arpit1912/CO_simulator/contributors
# zhxinhust/deep-learning-specialization-coursera
# 31 0
# AdalbertoCq/Deep-Learning-Specialization-Coursera
# 30 0
# shobhi1310/museum
# 7 0
# https://api.github.com/repos/arpit1912/museum_project/contributors
# oppia/oppia
# 11131 0
# https://api.github.com/repos/arpit1912/Projects/contributors
# https://api.github.com/repos/arpit1912/RepoSummariser/contributors
# https://api.github.com/repos/arpit1912/SE-gamedev/contributors
# https://api.github.com/repos/arpit1912/slack/contributors
# https://api.github.com/repos/arpit1912/SWE_Project/contributors
# krish7777/SWE_Project
# arpit1912  this is the match we found
# 120 47
# https://api.github.com/repos/arpit1912/tensorflow_models/contributors
# dinkar64/compiler_project
# sam3926  this is the match we found
# 9 1
# https://api.github.com/repos/sam3926/CO_simulator/contributors
# krish7777/food4all
# sam3926  this is the match we found
# 333 26
# AkhilaSriManasa/GitTutorial_1
# sam3926  this is the match we found
# 45 1
# https://api.github.com/repos/sam3926/hello-world/contributors
# arpit1912/RepoSummariser
# sam3926  this is the match we found
# 8 3
# arpit1912/SE-gamedev
# sam3926  this is the match we found
# 86 41

# %%
def repo_details(owner,repo,token):
    query_url = f"https://api.github.com/repos/{owner}/{repo}"
    #print("Inside the repo Detail section")
    #print(query_url)
    params = {
        "state": "open",
    }
    headers = {'Authorization': f'token {token}'}
    r = requests.get(query_url, headers=headers, params=params)
    return r.json()

# %%
def get_contributions_list(owner,repo,token):
    query_url = f"https://api.github.com/repos/{owner}/{repo}/contributors?page=1&per_page=10000"
    params = {
        "state": "open",
    }
    #print(query_url)
    headers = {'Authorization': f'token {token}'}
    r = requests.get(query_url, headers=headers, params=params)
    data = r.json()
    #if data.get('Link') != None:
        #pprint (r.headers)
    #print (data)
    return r.json()

# %%
def calculated_contribution(owner,original_repo_contribution_data):
    total_contributions = 0
    user_contribution = 0

    for contributor in original_repo_contribution_data:
        if(contributor['contributions'] > 0):
            total_contributions += contributor['contributions']
            if(contributor['login'] == owner):
                print(contributor['login'], " this is the match we found")
                user_contribution = contributor['contributions']
            
    return total_contributions, user_contribution
